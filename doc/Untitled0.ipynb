# %%
# !git clone https://github.com/NguyenTrungHieuBW/cnn_rec
# Out:
# Cloning into 'cnn_rec'...
# remote: Enumerating objects: 122, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 122 (delta 7), reused 16 (delta 4), pack-reused 101
# Receiving objects: 100% (122/122), 75.29 MiB | 24.98 MiB/s, done.
# Resolving deltas: 100% (35/35), done.
# Updating files: 100% (35/35), done.

# %%
# %cd cnn_rec
# Out:
# /content/cnn_rec/cnn_rec/cnn_rec/cnn_rec/cnn_rec/cnn_rec/cnn_rec

# %%
# !python train_caser.py
# Out:
# Namespace(train_root='datasets/amazon4/test/train.txt', test_root='datasets/amazon4/test/test.txt', L=5, T=3, n_iter=50, seed=1234, batch_size=512, learning_rate=0.001, l2=1e-06, neg_samples=3, use_cuda=True)
# Namespace(d=50, nv=4, nh=16, drop=0.5, ac_conv='relu', ac_fc='relu', L=5)
# total training instances: 141246
# 7746
# 37406
# Epoch 1 [42.8 s]	loss=1.1762 [0.0 s]
# Epoch 2 [3.1 s]	loss=1.0401 [0.0 s]
# Epoch 3 [3.1 s]	loss=0.9243 [0.0 s]
# Epoch 4 [3.1 s]	loss=0.8189 [0.0 s]
# Epoch 5 [4.9 s]	loss=0.7282 [0.0 s]
# Epoch 6 [3.0 s]	loss=0.6511 [0.0 s]
# Epoch 7 [3.1 s]	loss=0.5865 [0.0 s]
# Epoch 8 [3.0 s]	loss=0.5321 [0.0 s]
# Epoch 9 [3.0 s]	loss=0.4854 [0.0 s]
# 7746
# 38407
# 7746
# 37406
